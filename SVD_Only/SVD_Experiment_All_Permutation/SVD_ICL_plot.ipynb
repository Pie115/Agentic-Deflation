# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ICL_examples = [0,1,2,3,4,5]

avg_RMSE_none = [70.399451, 65.255030, 64.151859, 63.499569, 63.932280, 63.136393]
std_RMSE_none = [13.835243, 9.927686, 9.811025, 9.715364, 10.215121, 9.988645]

avg_RMSE_naive_sort = [66.727581, 62.578749, 61.581639, 61.676619, 61.251990, 61.214312]
std_RMSE_naive_sort = [8.277653, 7.989886, 7.455521, 7.594596, 7.284583, 7.282534]

avg_RMSE_group_n_teach = [68.344074, 62.925709, 62.260812, 61.719740, 62.198099, 61.324157]
std_RMSE_group_n_teach = [11.342539, 8.830073, 7.578411, 8.240291, 9.372148, 7.652036]

# %%
avg_SSIM_none = [0.580057, 0.653651, 0.661293, 0.670167, 0.660377, 0.673371]
std_SSIM_none = [0.165198, 0.123572, 0.120295, 0.119430, 0.132390, 0.115046]

avg_SSIM_naive_sort = [0.583019, 0.644674, 0.660052, 0.654861, 0.661447, 0.661240]
std_SSIM_naive_sort = [0.126746, 0.113349, 0.105830, 0.113566, 0.103927, 0.106003]

avg_SSIM_group_n_teach = [0.598986, 0.676639, 0.681555, 0.654861, 0.661447, 0.661240]
std_SSIM_group_n_teach = [0.143904, 0.107527, 0.090407, 0.113566, 0.103927, 0.106003]

# %%
avg_RMSE_numpy = 54.300136
avg_SSIM_numpy = 0.762102

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

avg_RMSE_numpy = 54.300136
avg_SSIM_numpy = 0.762102

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(ICL_examples, avg_RMSE_none, label='None', marker='o')
ax1.plot(ICL_examples, avg_RMSE_naive_sort, label='Naive Sort', marker='s')
ax1.plot(ICL_examples, avg_RMSE_group_n_teach, label='Group-n-Teach', marker='^')
ax1.axhline(y=avg_RMSE_numpy, color='red', linestyle='--', label='NumPy Baseline')
ax1.set_title("RMSE vs ICL Examples")
ax1.set_xlabel("ICL Examples")
ax1.set_ylabel("RMSE")
ax1.legend()
ax1.grid(True)

ax2.plot(ICL_examples, avg_SSIM_none, label='None', marker='o')
ax2.plot(ICL_examples, avg_SSIM_naive_sort, label='Naive Sort', marker='s')
ax2.plot(ICL_examples, avg_SSIM_group_n_teach, label='Group-n-Teach', marker='^')
ax2.axhline(y=avg_SSIM_numpy, color='red', linestyle='--', label='NumPy Baseline')
ax2.set_title("SSIM vs ICL Examples")
ax2.set_xlabel("ICL Examples")
ax2.set_ylabel("SSIM")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig("RMSE-SSIM_plot.png")

# %%
avg_RMSE_naive_sort_cifar10 = [93.296409, 70.406790, 61.098098, 62.523630, 56.636648, 54.657567]
std_RMSE_naive_sort_cifar10 = [25.789727, 20.051536, 20.035459, 22.065423, 19.123111, 16.623158]

# %%
avg_SSIM_naive_sort_cifar10 = [0.175212, 0.271608, 0.313803, 0.300458, 0.314059, 0.317042]
std_SSIM_naive_sort_cifar10 = [0.111613, 0.132221, 0.145881, 0.151225, 0.143500, 0.136472]

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

avg_RMSE_numpy = 33.251059
avg_SSIM_numpy = 0.455275

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(ICL_examples, avg_RMSE_naive_sort_cifar10, label='Naive Sort')
ax1.axhline(y=avg_RMSE_numpy, color='red', linestyle='--', label='NumPy Baseline')
ax1.set_title("RMSE vs ICL Examples")
ax1.set_xlabel("ICL Examples")
ax1.set_ylabel("RMSE")
ax1.legend()
ax1.grid(True)

ax2.plot(ICL_examples, avg_SSIM_naive_sort_cifar10, label='Naive Sort')
ax2.axhline(y=avg_SSIM_numpy, color='red', linestyle='--', label='NumPy Baseline')
ax2.set_title("SSIM vs ICL Examples")
ax2.set_xlabel("ICL Examples")
ax2.set_ylabel("SSIM")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.title("Digits plots")
plt.savefig("RMSE-SSIM_plot.png")
